# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanchauhan0276/forest-fire-predivtion/blob/main/NASA-FIRNS/MODIS_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("modis_2024_India.csv")

# %%
df.head(5)
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   23.7690    86.3923       303.8   3.6    1.8  2024-01-01       346
# 1   34.0996    74.9958       305.7   1.0    1.0  2024-01-01       522
# 2   31.0805    78.2029       300.8   1.5    1.2  2024-01-01       522
# 3   34.0908    74.9942       300.5   1.0    1.0  2024-01-01       522
# 4   23.6291    74.3663       304.3   1.2    1.1  2024-01-01       524
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0     Terra      MODIS          13    61.03       291.9  27.5        D     2
# 1     Terra      MODIS          55    61.03       278.0  10.1        D     0
# 2     Terra      MODIS          18    61.03       284.3  11.5        D     0
# 3     Terra      MODIS          28    61.03       280.4   6.9        D     0
# 4     Terra      MODIS          43    61.03       292.2   5.1        D     0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74029 entries, 0 to 74028
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    74029 non-null  float64
#  1   longitude   74029 non-null  float64
#  2   brightness  74029 non-null  float64
#  3   scan        74029 non-null  float64
#  4   track       74029 non-null  float64
#  5   acq_date    74029 non-null  object
#  6   acq_time    74029 non-null  int64
#  7   satellite   74029 non-null  object
#  8   instrument  74029 non-null  object
#  9   confidence  74029 non-null  int64
#  10  version     74029 non-null  float64
#  11  bright_t31  74029 non-null  float64
#  12  frp         74029 non-null  float64
#  13  daynight    74029 non-null  object
#  14  type        74029 non-null  int64
# dtypes: float64(8), int64(3), object(4)
# memory usage: 8.5+ MB
